# %% [markdown]
# <a href="https://colab.research.google.com/github/Benjitaduratames/labo2025v/blob/main/src/ensembles/594_TareaHogar_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 02 10:54:17 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454465    77.7 1454465  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5940
PARAM$semilla_primigenia <- 182821

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L), #mayor a cero y a mayor numero mayor precisión con learning rate pequeño
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3), #default 0.1, tiene que ser mayor a cero con small learning rate
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L),
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 100 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83398
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sun Nov 02 11:28:10 PM 2025 AUC 0.926118281397844
#
# Sun Nov 02 11:29:50 PM 2025 AUC 0.927446901785363
#
# Sun Nov 02 11:32:24 PM 2025 AUC 0.926132588685024
#
# Sun Nov 02 11:35:39 PM 2025 AUC 0.9275536164479
#
# Sun Nov 02 11:36:25 PM 2025 AUC 0.924538362328807
#
# Sun Nov 02 11:38:16 PM 2025 AUC 0.922371251218557
#
# Sun Nov 02 11:39:00 PM 2025 AUC 0.924573329398188
#
# Sun Nov 02 11:41:40 PM 2025 AUC 0.926625426083926
#
# Sun Nov 02 11:43:18 PM 2025 AUC 0.925399897664078
#
# Sun Nov 02 11:45:28 PM 2025 AUC 0.92521144688319
#
# Sun Nov 02 11:45:38 PM 2025 AUC 0.926785139694173
#
# Sun Nov 02 11:48:31 PM 2025 AUC 0.925527582282257
#
# Sun Nov 02 11:49:06 PM 2025 AUC 0.92488423477403
#
# Sun Nov 02 11:49:35 PM 2025 AUC 0.92355150468134
#
# Sun Nov 02 11:52:21 PM 2025 AUC 0.921941955890361
#
# Sun Nov 02 11:55:25 PM 2025 AUC 0.92320318706883
#
# Sun Nov 02 11:55:47 PM 2025 AUC 0.925534534884075
#
# Sun Nov 02 11:57:44 PM 2025 AUC 0.925391646824018
#
# Sun Nov 02 11:58:34 PM 2025 AUC 0.921625420549554
#
# Mon Nov 03 12:01:17 AM 2025 AUC 0.925685807041075
#
# [mbo] 0: num_iterations=753; learning_rate=0.0949; feature_fraction=0.226; num_leaves=457; min_data_in_leaf=6381 : y = 0.926 : 70.8 secs : initdesign
#
# [mbo] 0: num_iterations=1095; learning_rate=0.0774; feature_fraction=0.62; num_leaves=1337; min_data_in_leaf=3016 : y = 0.927 : 100.2 secs : initdesign
#
# [mbo] 0: num_iterations=1244; learning_rate=0.12; feature_fraction=0.497; num_leaves=792; min_data_in_leaf=2692 : y = 0.926 : 154.2 secs : initdesign
#
# [mbo] 0: num_iterations=1668; learning_rate=0.15; feature_fraction=0.67; num_leaves=1604; min_data_in_leaf=731 : y = 0.928 : 194.4 secs : initdesign
#
# [mbo] 0: num_iterations=383; learning_rate=0.0217; feature_fraction=0.517; num_leaves=569; min_data_in_leaf=4738 : y = 0.925 : 45.9 secs : initdesign
#
# [mbo] 0: num_iterations=1182; learning_rate=0.244; feature_fraction=0.279; num_leaves=1150; min_data_in_leaf=7047 : y = 0.922 : 111.8 secs : initdesign
#
# [mbo] 0: num_iterations=640; learning_rate=0.233; feature_fraction=0.804; num_leaves=279; min_data_in_leaf=6615 : y = 0.925 : 43.2 secs : initdesign
#
# [mbo] 0: num_iterations=1534; learning_rate=0.025; feature_fraction=0.321; num_leaves=1483; min_data_in_leaf=4034 : y = 0.927 : 160.4 secs : initdesign
#
# [mbo] 0: num_iterations=885; learning_rate=0.127; feature_fraction=0.409; num_leaves=1120; min_data_in_leaf=4839 : y = 0.925 : 98.3 secs : initdesign
#
# [mbo] 0: num_iterations=1398; learning_rate=0.184; feature_fraction=0.892; num_leaves=367; min_data_in_leaf=2239 : y = 0.925 : 130.1 secs : initdesign
#
# [mbo] 0: num_iterations=83; learning_rate=0.19; feature_fraction=0.911; num_leaves=850; min_data_in_leaf=1917 : y = 0.927 : 10.0 secs : initdesign
#
# [mbo] 0: num_iterations=1616; learning_rate=0.165; feature_fraction=0.34; num_leaves=131; min_data_in_leaf=3867 : y = 0.926 : 172.9 secs : initdesign
#
# [mbo] 0: num_iterations=472; learning_rate=0.0453; feature_fraction=0.707; num_leaves=1765; min_data_in_leaf=5680 : y = 0.925 : 34.6 secs : initdesign
#
# [mbo] 0: num_iterations=282; learning_rate=0.299; feature_fraction=0.836; num_leaves=1865; min_data_in_leaf=1576 : y = 0.924 : 29.4 secs : initdesign
#
# [mbo] 0: num_iterations=1963; learning_rate=0.212; feature_fraction=0.17; num_leaves=1318; min_data_in_leaf=7669 : y = 0.922 : 165.7 secs : initdesign
#
# [mbo] 0: num_iterations=1873; learning_rate=0.27; feature_fraction=0.987; num_leaves=1684; min_data_in_leaf=833 : y = 0.923 : 183.9 secs : initdesign
#
# [mbo] 0: num_iterations=181; learning_rate=0.275; feature_fraction=0.452; num_leaves=30; min_data_in_leaf=3415 : y = 0.926 : 22.0 secs : initdesign
#
# [mbo] 0: num_iterations=1822; learning_rate=0.0612; feature_fraction=0.735; num_leaves=718; min_data_in_leaf=7223 : y = 0.925 : 116.9 secs : initdesign
#
# [mbo] 0: num_iterations=602; learning_rate=0.224; feature_fraction=0.133; num_leaves=1979; min_data_in_leaf=5467 : y = 0.922 : 50.0 secs : initdesign
#
# [mbo] 0: num_iterations=948; learning_rate=0.11; feature_fraction=0.562; num_leaves=1000; min_data_in_leaf=377 : y = 0.926 : 163.4 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:04:31 AM 2025 AUC 0.928050405358891
#
# [mbo] 1: num_iterations=1841; learning_rate=0.0836; feature_fraction=0.614; num_leaves=1615; min_data_in_leaf=2111 : y = 0.928 : 193.2 secs : infill_ei
#
# Mon Nov 03 12:08:21 AM 2025 AUC 0.927996188169006
#
# [mbo] 2: num_iterations=2031; learning_rate=0.0828; feature_fraction=0.982; num_leaves=1494; min_data_in_leaf=1856 : y = 0.928 : 229.3 secs : infill_ei
#
# Mon Nov 03 12:11:35 AM 2025 AUC 0.92634710636219
#
# [mbo] 3: num_iterations=2045; learning_rate=0.0713; feature_fraction=0.153; num_leaves=1497; min_data_in_leaf=2225 : y = 0.926 : 194.2 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:14:07 AM 2025 AUC 0.926647624594315
#
# [mbo] 4: num_iterations=1619; learning_rate=0.088; feature_fraction=0.983; num_leaves=1698; min_data_in_leaf=2545 : y = 0.927 : 150.9 secs : infill_ei
#
# Mon Nov 03 12:17:39 AM 2025 AUC 0.927782635040072
#
# [mbo] 5: num_iterations=1870; learning_rate=0.0891; feature_fraction=0.715; num_leaves=1493; min_data_in_leaf=1352 : y = 0.928 : 212.6 secs : infill_ei
#
# Mon Nov 03 12:20:19 AM 2025 AUC 0.927937502741447
#
# [mbo] 6: num_iterations=1532; learning_rate=0.118; feature_fraction=0.722; num_leaves=1469; min_data_in_leaf=1877 : y = 0.928 : 159.1 secs : infill_ei
#
# Mon Nov 03 12:23:43 AM 2025 AUC 0.928080903635861
#
# [mbo] 7: num_iterations=2048; learning_rate=0.0711; feature_fraction=0.675; num_leaves=1477; min_data_in_leaf=2297 : y = 0.928 : 203.5 secs : infill_ei
#
# Saved the current state after iteration 8 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:28:19 AM 2025 AUC 0.928917593226335
#
# [mbo] 8: num_iterations=2046; learning_rate=0.0786; feature_fraction=0.802; num_leaves=1419; min_data_in_leaf=833 : y = 0.929 : 275.4 secs : infill_ei
#
# Mon Nov 03 12:33:12 AM 2025 AUC 0.927536502853961
#
# [mbo] 9: num_iterations=2043; learning_rate=0.068; feature_fraction=0.903; num_leaves=1541; min_data_in_leaf=691 : y = 0.928 : 293.0 secs : infill_ei
#
# Mon Nov 03 12:36:42 AM 2025 AUC 0.928838032287889
#
# [mbo] 10: num_iterations=2045; learning_rate=0.0837; feature_fraction=0.841; num_leaves=1323; min_data_in_leaf=1989 : y = 0.929 : 209.5 secs : infill_ei
#
# Saved the current state after iteration 11 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:40:15 AM 2025 AUC 0.927192259347051
#
# [mbo] 11: num_iterations=2044; learning_rate=0.0704; feature_fraction=0.949; num_leaves=1382; min_data_in_leaf=1718 : y = 0.927 : 212.3 secs : infill_ei
#
# Mon Nov 03 12:44:59 AM 2025 AUC 0.927801861391465
#
# [mbo] 12: num_iterations=2046; learning_rate=0.081; feature_fraction=0.741; num_leaves=1289; min_data_in_leaf=426 : y = 0.928 : 284.1 secs : infill_ei
#
# Mon Nov 03 12:49:06 AM 2025 AUC 0.926832151471082
#
# [mbo] 13: num_iterations=2047; learning_rate=0.0814; feature_fraction=0.814; num_leaves=2048; min_data_in_leaf=1092 : y = 0.927 : 246.7 secs : infill_ei
#
# Saved the current state after iteration 14 in the file bayesiana.RDATA.
#
# Mon Nov 03 12:53:20 AM 2025 AUC 0.9286955448858
#
# [mbo] 14: num_iterations=2047; learning_rate=0.083; feature_fraction=0.847; num_leaves=1260; min_data_in_leaf=967 : y = 0.929 : 253.3 secs : infill_ei
#
# Mon Nov 03 12:57:32 AM 2025 AUC 0.927796565096445
#
# [mbo] 15: num_iterations=2048; learning_rate=0.125; feature_fraction=0.835; num_leaves=1430; min_data_in_leaf=1263 : y = 0.928 : 251.7 secs : infill_ei
#
# Mon Nov 03 01:00:53 AM 2025 AUC 0.928336119148729
#
# [mbo] 16: num_iterations=2024; learning_rate=0.0796; feature_fraction=0.799; num_leaves=1174; min_data_in_leaf=2055 : y = 0.928 : 200.8 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:04:44 AM 2025 AUC 0.927223104007592
#
# [mbo] 17: num_iterations=2036; learning_rate=0.0807; feature_fraction=0.829; num_leaves=1461; min_data_in_leaf=1402 : y = 0.927 : 230.5 secs : infill_ei
#
# Mon Nov 03 01:09:08 AM 2025 AUC 0.927645027665525
#
# [mbo] 18: num_iterations=2009; learning_rate=0.0949; feature_fraction=0.694; num_leaves=1035; min_data_in_leaf=843 : y = 0.928 : 264.1 secs : infill_ei
#
# Mon Nov 03 01:12:38 AM 2025 AUC 0.928140825719501
#
# [mbo] 19: num_iterations=2044; learning_rate=0.0769; feature_fraction=0.632; num_leaves=1209; min_data_in_leaf=2168 : y = 0.928 : 208.6 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:15:42 AM 2025 AUC 0.928319247184513
#
# [mbo] 20: num_iterations=1821; learning_rate=0.0947; feature_fraction=0.82; num_leaves=1204; min_data_in_leaf=1933 : y = 0.928 : 184.3 secs : infill_ei
#
# Mon Nov 03 01:19:46 AM 2025 AUC 0.928316560992537
#
# [mbo] 21: num_iterations=1938; learning_rate=0.0925; feature_fraction=0.702; num_leaves=1406; min_data_in_leaf=892 : y = 0.928 : 243.4 secs : infill_ei
#
# Mon Nov 03 01:23:15 AM 2025 AUC 0.928557897365975
#
# [mbo] 22: num_iterations=1680; learning_rate=0.0792; feature_fraction=0.68; num_leaves=1307; min_data_in_leaf=831 : y = 0.929 : 208.2 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:26:27 AM 2025 AUC 0.926631006258087
#
# [mbo] 23: num_iterations=2048; learning_rate=0.0905; feature_fraction=0.754; num_leaves=1407; min_data_in_leaf=1990 : y = 0.927 : 191.5 secs : infill_ei
#
# Mon Nov 03 01:30:27 AM 2025 AUC 0.925469040587502
#
# [mbo] 24: num_iterations=1945; learning_rate=0.0785; feature_fraction=0.782; num_leaves=994; min_data_in_leaf=16 : y = 0.925 : 239.7 secs : infill_ei
#
# Mon Nov 03 01:33:32 AM 2025 AUC 0.92802161365784
#
# [mbo] 25: num_iterations=2047; learning_rate=0.0853; feature_fraction=0.86; num_leaves=1184; min_data_in_leaf=2298 : y = 0.928 : 185.1 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:37:38 AM 2025 AUC 0.928980943907183
#
# [mbo] 26: num_iterations=1927; learning_rate=0.0611; feature_fraction=0.99; num_leaves=1329; min_data_in_leaf=837 : y = 0.929 : 245.8 secs : infill_ei
#
# Mon Nov 03 01:41:43 AM 2025 AUC 0.926455883411189
#
# [mbo] 27: num_iterations=1941; learning_rate=0.117; feature_fraction=0.951; num_leaves=1427; min_data_in_leaf=513 : y = 0.926 : 244.7 secs : infill_ei
#
# Mon Nov 03 01:46:25 AM 2025 AUC 0.928263503844467
#
# [mbo] 28: num_iterations=1992; learning_rate=0.0787; feature_fraction=0.802; num_leaves=1328; min_data_in_leaf=718 : y = 0.928 : 281.6 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:48:25 AM 2025 AUC 0.928087053404647
#
# [mbo] 29: num_iterations=1165; learning_rate=0.0753; feature_fraction=0.853; num_leaves=1137; min_data_in_leaf=2036 : y = 0.928 : 119.3 secs : infill_ei
#
# Mon Nov 03 01:51:40 AM 2025 AUC 0.92572685025744
#
# [mbo] 30: num_iterations=2045; learning_rate=0.105; feature_fraction=0.8; num_leaves=1448; min_data_in_leaf=3069 : y = 0.926 : 194.3 secs : infill_ei
#
# Mon Nov 03 01:56:49 AM 2025 AUC 0.927849439462631
#
# [mbo] 31: num_iterations=1870; learning_rate=0.0694; feature_fraction=0.645; num_leaves=1422; min_data_in_leaf=348 : y = 0.928 : 309.0 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Mon Nov 03 01:59:28 AM 2025 AUC 0.927433694886243
#
# [mbo] 32: num_iterations=1508; learning_rate=0.0842; feature_fraction=0.866; num_leaves=309; min_data_in_leaf=1971 : y = 0.927 : 158.2 secs : infill_ei
#
# Mon Nov 03 02:02:47 AM 2025 AUC 0.927763352742513
#
# [mbo] 33: num_iterations=1846; learning_rate=0.0803; feature_fraction=0.69; num_leaves=1200; min_data_in_leaf=1898 : y = 0.928 : 199.0 secs : infill_ei
#
# Mon Nov 03 02:06:48 AM 2025 AUC 0.92948204097525
#
# [mbo] 34: num_iterations=1773; learning_rate=0.0617; feature_fraction=0.771; num_leaves=1396; min_data_in_leaf=912 : y = 0.929 : 240.2 secs : infill_ei
#
# Mon Nov 03 02:07:31 AM 2025 AUC 0.928270780634775
#
# [mbo] 35: num_iterations=411; learning_rate=0.081; feature_fraction=0.978; num_leaves=1300; min_data_in_leaf=2122 : y = 0.928 : 42.0 secs : infill_ei
#
# Saved the current state after iteration 36 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:11:00 AM 2025 AUC 0.928845265917745
#
# [mbo] 36: num_iterations=1555; learning_rate=0.0313; feature_fraction=0.728; num_leaves=1538; min_data_in_leaf=910 : y = 0.929 : 208.8 secs : infill_ei
#
# Mon Nov 03 02:14:10 AM 2025 AUC 0.9285394212415
#
# [mbo] 37: num_iterations=1402; learning_rate=0.0852; feature_fraction=0.646; num_leaves=1476; min_data_in_leaf=859 : y = 0.929 : 189.3 secs : infill_ei
#
# Mon Nov 03 02:15:32 AM 2025 AUC 0.928851909032806
#
# [mbo] 38: num_iterations=602; learning_rate=0.0612; feature_fraction=0.748; num_leaves=1428; min_data_in_leaf=874 : y = 0.929 : 81.3 secs : infill_ei
#
# Mon Nov 03 02:19:07 AM 2025 AUC 0.929195512554908
#
# [mbo] 39: num_iterations=1391; learning_rate=0.0432; feature_fraction=0.775; num_leaves=1422; min_data_in_leaf=553 : y = 0.929 : 215.4 secs : infill_ei
#
# Saved the current state after iteration 40 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:22:25 AM 2025 AUC 0.928024008309547
#
# [mbo] 40: num_iterations=1464; learning_rate=0.0447; feature_fraction=0.81; num_leaves=818; min_data_in_leaf=888 : y = 0.928 : 196.7 secs : infill_ei
#
# Mon Nov 03 02:22:57 AM 2025 AUC 0.926058740505216
#
# [mbo] 41: num_iterations=363; learning_rate=0.213; feature_fraction=0.748; num_leaves=1157; min_data_in_leaf=3246 : y = 0.926 : 32.1 secs : infill_ei
#
# Mon Nov 03 02:26:40 AM 2025 AUC 0.928961004122893
#
# [mbo] 42: num_iterations=1643; learning_rate=0.0418; feature_fraction=0.81; num_leaves=1382; min_data_in_leaf=883 : y = 0.929 : 221.8 secs : infill_ei
#
# Mon Nov 03 02:28:54 AM 2025 AUC 0.927299873016831
#
# [mbo] 43: num_iterations=1542; learning_rate=0.0567; feature_fraction=0.732; num_leaves=1419; min_data_in_leaf=3522 : y = 0.927 : 134.4 secs : infill_ei
#
# Mon Nov 03 02:32:04 AM 2025 AUC 0.927669693933445
#
# [mbo] 44: num_iterations=1872; learning_rate=0.0597; feature_fraction=0.793; num_leaves=1292; min_data_in_leaf=2169 : y = 0.928 : 188.6 secs : infill_ei
#
# Saved the current state after iteration 45 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:34:03 AM 2025 AUC 0.927455157032496
#
# [mbo] 45: num_iterations=1044; learning_rate=0.133; feature_fraction=0.655; num_leaves=1452; min_data_in_leaf=1590 : y = 0.927 : 118.6 secs : infill_ei
#
# Mon Nov 03 02:38:41 AM 2025 AUC 0.928511828711612
#
# [mbo] 46: num_iterations=1568; learning_rate=0.0614; feature_fraction=0.666; num_leaves=1611; min_data_in_leaf=356 : y = 0.929 : 278.0 secs : infill_ei
#
# Mon Nov 03 02:39:24 AM 2025 AUC 0.928888332690804
#
# [mbo] 47: num_iterations=320; learning_rate=0.0739; feature_fraction=0.999; num_leaves=1270; min_data_in_leaf=965 : y = 0.929 : 42.5 secs : infill_ei
#
# Mon Nov 03 02:43:30 AM 2025 AUC 0.929454113981219
#
# [mbo] 48: num_iterations=1520; learning_rate=0.0447; feature_fraction=0.689; num_leaves=1935; min_data_in_leaf=572 : y = 0.929 : 245.6 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:47:17 AM 2025 AUC 0.92905024543296
#
# [mbo] 49: num_iterations=1436; learning_rate=0.0513; feature_fraction=0.735; num_leaves=1719; min_data_in_leaf=606 : y = 0.929 : 225.9 secs : infill_ei
#
# Mon Nov 03 02:50:22 AM 2025 AUC 0.929851949335118
#
# [mbo] 50: num_iterations=1347; learning_rate=0.0658; feature_fraction=0.774; num_leaves=1452; min_data_in_leaf=891 : y = 0.93 : 185.0 secs : infill_ei
#
# Mon Nov 03 02:52:35 AM 2025 AUC 0.929054604773389
#
# [mbo] 51: num_iterations=949; learning_rate=0.0355; feature_fraction=0.779; num_leaves=1704; min_data_in_leaf=814 : y = 0.929 : 132.1 secs : infill_ei
#
# Mon Nov 03 02:55:23 AM 2025 AUC 0.926137038140094
#
# [mbo] 52: num_iterations=1231; learning_rate=0.13; feature_fraction=0.775; num_leaves=1453; min_data_in_leaf=892 : y = 0.926 : 167.3 secs : infill_ei
#
# Saved the current state after iteration 53 in the file bayesiana.RDATA.
#
# Mon Nov 03 02:58:23 AM 2025 AUC 0.929080192401523
#
# [mbo] 53: num_iterations=1306; learning_rate=0.0637; feature_fraction=0.851; num_leaves=1281; min_data_in_leaf=818 : y = 0.929 : 179.2 secs : infill_ei
#
# Mon Nov 03 03:02:50 AM 2025 AUC 0.927149293248987
#
# [mbo] 54: num_iterations=1582; learning_rate=0.0611; feature_fraction=0.771; num_leaves=1567; min_data_in_leaf=514 : y = 0.927 : 266.5 secs : infill_ei
#
# Mon Nov 03 03:04:36 AM 2025 AUC 0.923663470874761
#
# [mbo] 55: num_iterations=973; learning_rate=0.199; feature_fraction=0.323; num_leaves=497; min_data_in_leaf=5266 : y = 0.924 : 106.1 secs : infill_ei
#
# Mon Nov 03 03:06:04 AM 2025 AUC 0.924471864226909
#
# [mbo] 56: num_iterations=1147; learning_rate=0.269; feature_fraction=0.985; num_leaves=329; min_data_in_leaf=6831 : y = 0.924 : 87.0 secs : infill_ei
#
# Saved the current state after iteration 57 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:08:51 AM 2025 AUC 0.928974816480003
#
# [mbo] 57: num_iterations=1302; learning_rate=0.0511; feature_fraction=0.751; num_leaves=1386; min_data_in_leaf=987 : y = 0.929 : 166.6 secs : infill_ei
#
# Mon Nov 03 03:12:26 AM 2025 AUC 0.929297990626861
#
# [mbo] 58: num_iterations=1328; learning_rate=0.0387; feature_fraction=0.665; num_leaves=1611; min_data_in_leaf=439 : y = 0.929 : 214.5 secs : infill_ei
#
# Mon Nov 03 03:15:10 AM 2025 AUC 0.928288888740301
#
# [mbo] 59: num_iterations=1214; learning_rate=0.0473; feature_fraction=0.677; num_leaves=1745; min_data_in_leaf=840 : y = 0.928 : 164.2 secs : infill_ei
#
# Mon Nov 03 03:17:17 AM 2025 AUC 0.927006046293771
#
# [mbo] 60: num_iterations=1214; learning_rate=0.0536; feature_fraction=0.774; num_leaves=1175; min_data_in_leaf=1684 : y = 0.927 : 126.1 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:19:45 AM 2025 AUC 0.928203472304068
#
# [mbo] 61: num_iterations=1249; learning_rate=0.0503; feature_fraction=0.814; num_leaves=1484; min_data_in_leaf=1134 : y = 0.928 : 147.4 secs : infill_ei
#
# Mon Nov 03 03:21:07 AM 2025 AUC 0.927169716809175
#
# [mbo] 62: num_iterations=740; learning_rate=0.0744; feature_fraction=0.873; num_leaves=837; min_data_in_leaf=1425 : y = 0.927 : 81.4 secs : infill_ei
#
# Mon Nov 03 03:23:47 AM 2025 AUC 0.92746007580712
#
# [mbo] 63: num_iterations=1334; learning_rate=0.0578; feature_fraction=0.764; num_leaves=1466; min_data_in_leaf=1229 : y = 0.927 : 159.9 secs : infill_ei
#
# Mon Nov 03 03:25:27 AM 2025 AUC 0.928444313609207
#
# [mbo] 64: num_iterations=746; learning_rate=0.0708; feature_fraction=0.79; num_leaves=1294; min_data_in_leaf=894 : y = 0.928 : 99.8 secs : infill_ei
#
# Mon Nov 03 03:28:45 AM 2025 AUC 0.927767508072574
#
# [mbo] 65: num_iterations=1007; learning_rate=0.0424; feature_fraction=0.725; num_leaves=1762; min_data_in_leaf=320 : y = 0.928 : 197.0 secs : infill_ei
#
# Saved the current state after iteration 66 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:32:57 AM 2025 AUC 0.929543082674052
#
# [mbo] 66: num_iterations=1867; learning_rate=0.0382; feature_fraction=0.766; num_leaves=1562; min_data_in_leaf=864 : y = 0.93 : 251.9 secs : infill_ei
#
# Mon Nov 03 03:34:39 AM 2025 AUC 0.928677959533089
#
# [mbo] 67: num_iterations=761; learning_rate=0.065; feature_fraction=0.802; num_leaves=1392; min_data_in_leaf=838 : y = 0.929 : 101.4 secs : infill_ei
#
# Mon Nov 03 03:38:12 AM 2025 AUC 0.930218732009388
#
# [mbo] 68: num_iterations=1399; learning_rate=0.0286; feature_fraction=0.733; num_leaves=1855; min_data_in_leaf=596 : y = 0.93 : 212.6 secs : infill_ei
#
# Mon Nov 03 03:40:33 AM 2025 AUC 0.924498968228296
#
# [mbo] 69: num_iterations=1322; learning_rate=0.236; feature_fraction=0.29; num_leaves=778; min_data_in_leaf=4092 : y = 0.924 : 140.5 secs : infill_ei
#
# Saved the current state after iteration 70 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:45:35 AM 2025 AUC 0.929560670666341
#
# [mbo] 70: num_iterations=1934; learning_rate=0.0306; feature_fraction=0.744; num_leaves=1902; min_data_in_leaf=591 : y = 0.93 : 301.5 secs : infill_ei
#
# Mon Nov 03 03:49:03 AM 2025 AUC 0.929262379159537
#
# [mbo] 71: num_iterations=1395; learning_rate=0.033; feature_fraction=0.737; num_leaves=1551; min_data_in_leaf=645 : y = 0.929 : 206.4 secs : infill_ei
#
# Mon Nov 03 03:52:31 AM 2025 AUC 0.928724740889081
#
# [mbo] 72: num_iterations=1460; learning_rate=0.027; feature_fraction=0.689; num_leaves=1869; min_data_in_leaf=696 : y = 0.929 : 207.2 secs : infill_ei
#
# Saved the current state after iteration 73 in the file bayesiana.RDATA.
#
# Mon Nov 03 03:56:20 AM 2025 AUC 0.929314007492359
#
# [mbo] 73: num_iterations=1497; learning_rate=0.0214; feature_fraction=0.765; num_leaves=1946; min_data_in_leaf=549 : y = 0.929 : 228.3 secs : infill_ei
#
# Mon Nov 03 04:00:51 AM 2025 AUC 0.929605775938842
#
# [mbo] 74: num_iterations=1565; learning_rate=0.044; feature_fraction=0.608; num_leaves=1927; min_data_in_leaf=428 : y = 0.93 : 270.6 secs : infill_ei
#
# Mon Nov 03 04:04:16 AM 2025 AUC 0.929551315291476
#
# [mbo] 75: num_iterations=1254; learning_rate=0.0307; feature_fraction=0.632; num_leaves=1848; min_data_in_leaf=534 : y = 0.93 : 204.4 secs : infill_ei
#
# Saved the current state after iteration 76 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:06:32 AM 2025 AUC 0.929763268327384
#
# [mbo] 76: num_iterations=1007; learning_rate=0.063; feature_fraction=0.982; num_leaves=1422; min_data_in_leaf=933 : y = 0.93 : 135.7 secs : infill_ei
#
# Mon Nov 03 04:10:43 AM 2025 AUC 0.9293341535732
#
# [mbo] 77: num_iterations=1458; learning_rate=0.0316; feature_fraction=0.829; num_leaves=1849; min_data_in_leaf=423 : y = 0.929 : 251.1 secs : infill_ei
#
# Mon Nov 03 04:13:58 AM 2025 AUC 0.928854083457995
#
# [mbo] 78: num_iterations=1287; learning_rate=0.0312; feature_fraction=0.761; num_leaves=1898; min_data_in_leaf=583 : y = 0.929 : 194.1 secs : infill_ei
#
# Mon Nov 03 04:16:05 AM 2025 AUC 0.930178865812051
#
# [mbo] 79: num_iterations=919; learning_rate=0.0389; feature_fraction=0.857; num_leaves=2001; min_data_in_leaf=771 : y = 0.93 : 126.6 secs : infill_ei
#
# Saved the current state after iteration 80 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:20:47 AM 2025 AUC 0.929737559109453
#
# [mbo] 80: num_iterations=1857; learning_rate=0.0168; feature_fraction=0.727; num_leaves=1922; min_data_in_leaf=547 : y = 0.93 : 280.9 secs : infill_ei
#
# Mon Nov 03 04:25:50 AM 2025 AUC 0.929790928430208
#
# [mbo] 81: num_iterations=1903; learning_rate=0.063; feature_fraction=0.543; num_leaves=1435; min_data_in_leaf=865 : y = 0.93 : 302.4 secs : infill_ei
#
# Mon Nov 03 04:30:16 AM 2025 AUC 0.928160225702526
#
# [mbo] 82: num_iterations=1785; learning_rate=0.0159; feature_fraction=0.946; num_leaves=1831; min_data_in_leaf=596 : y = 0.928 : 265.1 secs : infill_ei
#
# Saved the current state after iteration 83 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:38:41 AM 2025 AUC 0.927302468578317
#
# [mbo] 83: num_iterations=1780; learning_rate=0.0292; feature_fraction=0.852; num_leaves=1784; min_data_in_leaf=27 : y = 0.927 : 504.5 secs : infill_ei
#
# Mon Nov 03 04:42:22 AM 2025 AUC 0.92968540897947
#
# [mbo] 84: num_iterations=1497; learning_rate=0.0248; feature_fraction=0.723; num_leaves=1134; min_data_in_leaf=530 : y = 0.93 : 220.4 secs : infill_ei
#
# Saved the current state after iteration 85 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:45:22 AM 2025 AUC 0.928907987460799
#
# [mbo] 85: num_iterations=1644; learning_rate=0.0389; feature_fraction=0.206; num_leaves=452; min_data_in_leaf=1327 : y = 0.929 : 179.7 secs : infill_ei
#
# Mon Nov 03 04:47:49 AM 2025 AUC 0.927584527692175
#
# [mbo] 86: num_iterations=1364; learning_rate=0.0759; feature_fraction=0.787; num_leaves=1531; min_data_in_leaf=1559 : y = 0.928 : 146.7 secs : infill_ei
#
# Mon Nov 03 04:51:53 AM 2025 AUC 0.929517604305948
#
# [mbo] 87: num_iterations=1436; learning_rate=0.0235; feature_fraction=0.726; num_leaves=1966; min_data_in_leaf=449 : y = 0.93 : 243.1 secs : infill_ei
#
# Mon Nov 03 04:53:52 AM 2025 AUC 0.929540488010567
#
# [mbo] 88: num_iterations=826; learning_rate=0.0234; feature_fraction=0.853; num_leaves=1904; min_data_in_leaf=688 : y = 0.93 : 118.5 secs : infill_ei
#
# Saved the current state after iteration 89 in the file bayesiana.RDATA.
#
# Mon Nov 03 04:58:23 AM 2025 AUC 0.929139106533703
#
# [mbo] 89: num_iterations=1578; learning_rate=0.0509; feature_fraction=0.577; num_leaves=1694; min_data_in_leaf=594 : y = 0.929 : 270.4 secs : infill_ei
#
# Mon Nov 03 05:01:46 AM 2025 AUC 0.928353849904847
#
# [mbo] 90: num_iterations=1693; learning_rate=0.0397; feature_fraction=0.601; num_leaves=1974; min_data_in_leaf=1648 : y = 0.928 : 203.0 secs : infill_ei
#
# Mon Nov 03 05:05:45 AM 2025 AUC 0.929313721847114
#
# [mbo] 91: num_iterations=1821; learning_rate=0.0165; feature_fraction=0.305; num_leaves=1856; min_data_in_leaf=998 : y = 0.929 : 238.1 secs : infill_ei
#
# Saved the current state after iteration 92 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:08:24 AM 2025 AUC 0.930211784941134
#
# [mbo] 92: num_iterations=1107; learning_rate=0.0203; feature_fraction=0.825; num_leaves=2005; min_data_in_leaf=649 : y = 0.93 : 158.9 secs : infill_ei
#
# Mon Nov 03 05:11:14 AM 2025 AUC 0.929897552981664
#
# [mbo] 93: num_iterations=1317; learning_rate=0.0236; feature_fraction=0.841; num_leaves=1995; min_data_in_leaf=832 : y = 0.93 : 169.0 secs : infill_ei
#
# Mon Nov 03 05:15:04 AM 2025 AUC 0.92960329931394
#
# [mbo] 94: num_iterations=1819; learning_rate=0.0494; feature_fraction=0.635; num_leaves=1005; min_data_in_leaf=930 : y = 0.93 : 230.0 secs : infill_ei
#
# Mon Nov 03 05:18:36 AM 2025 AUC 0.929095644330911
#
# [mbo] 95: num_iterations=1208; learning_rate=0.0222; feature_fraction=0.649; num_leaves=1752; min_data_in_leaf=371 : y = 0.929 : 211.0 secs : infill_ei
#
# Saved the current state after iteration 96 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:23:02 AM 2025 AUC 0.928336801741965
#
# [mbo] 96: num_iterations=1865; learning_rate=0.0445; feature_fraction=0.589; num_leaves=1272; min_data_in_leaf=937 : y = 0.928 : 265.9 secs : infill_ei
#
# Mon Nov 03 05:27:11 AM 2025 AUC 0.929194260756189
#
# [mbo] 97: num_iterations=1510; learning_rate=0.0288; feature_fraction=0.766; num_leaves=994; min_data_in_leaf=459 : y = 0.929 : 247.7 secs : infill_ei
#
# Mon Nov 03 05:30:32 AM 2025 AUC 0.930113084570411
#
# [mbo] 98: num_iterations=1221; learning_rate=0.0287; feature_fraction=0.541; num_leaves=1871; min_data_in_leaf=733 : y = 0.93 : 200.8 secs : infill_ei
#
# Saved the current state after iteration 99 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:34:09 AM 2025 AUC 0.929025674835691
#
# [mbo] 99: num_iterations=1381; learning_rate=0.0232; feature_fraction=0.844; num_leaves=1081; min_data_in_leaf=556 : y = 0.929 : 215.9 secs : infill_ei
#
# Mon Nov 03 05:35:35 AM 2025 AUC 0.927865259972811
#
# [mbo] 100: num_iterations=535; learning_rate=0.0618; feature_fraction=0.992; num_leaves=1033; min_data_in_leaf=597 : y = 0.928 : 86.1 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "feature_fraction" "num_leaves"
#  [5] "min_data_in_leaf" "y"                "dob"              "eol"
#  [9] "error.message"    "exec.time"        "ei"               "error.model"
# [13] "train.time"       "prop.type"        "propose.time"     "se"
# [17] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           1399    0.02863173        0.7332685       1855              596
# [1] 0.9302187

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 182821
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0
#
# $lambda_l2
# [1] 0
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1399
#
# $learning_rate
# [1] 0.02863173
#
# $feature_fraction
# [1] 0.7332685
#
# $num_leaves
# [1] 1855
#
# $min_data_in_leaf
# [1] 596

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 05:46:06 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
